# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3
import os

try:
    baglanti=sqlite3.connect('marka.db')
except:
    print("Veritabanı bağlantısı yapılamadı.")
    
class karsilastirma:
    def ram():
        a = baglanti.execute("Select ram from afirmasi  ").fetchall()
        b = baglanti.execute("Select ram from bfirmasi  ").fetchall()
        c = baglanti.execute("Select ram from cfirmasi  ").fetchall()
        plt.plot(a, color = "blue", label = "A firmasının telefonların Ramı")
        plt.plot(b, color = "red", label = "B firmasının telefonların Ramı")
        plt.plot(c, color = "pink", label = "c firmasının telefonların Ramı")
        plt.title("Firmaların telefonların ram karşılaştırmaları ")
        plt.xlabel("Firmalar")
        plt.ylabel("Oranlar")
        plt.legend()
        plt.show()
    def battery():
        a = baglanti.execute("Select battery from afirmasi  ").fetchall()
        b = baglanti.execute("Select battery from bfirmasi  ").fetchall()
        c = baglanti.execute("Select battery from cfirmasi  ").fetchall()
        plt.plot(a, color = "blue", label = "A firmasının telefonların bataryası")
        plt.plot(b, color = "red", label = "B firmasının telefonların bataryası")
        plt.plot(c, color = "pink", label = "c firmasının telefonların bataryası")
        plt.title("Firmaların telefonların batarya karşılaştırmaları ")
        plt.xlabel("Firmalar")
        plt.ylabel("Oranlar")
        plt.legend()
        plt.show()
    def camera():
        a = baglanti.execute("Select kamera from afirmasi  ").fetchall()
        b = baglanti.execute("Select kamera from bfirmasi  ").fetchall()
        c = baglanti.execute("Select kamera from cfirmasi  ").fetchall()
        plt.plot(a, color = "blue", label = "A firmasının telefonların kamera pikseli")
        plt.plot(b, color = "red", label = "B firmasının telefonların kamera pikseli")
        plt.plot(c, color = "pink", label = "c firmasının telefonların kamera pikseli")
        plt.title("Firmaların telefonların kamera piksel karşılaştırmaları ")
        plt.xlabel("Firmalar")
        plt.ylabel("Oranlar")
        plt.legend()
        plt.show()
    def hafiza():
        a = baglanti.execute("Select hafiza from afirmasi  ").fetchall()
        b = baglanti.execute("Select hafiza from bfirmasi  ").fetchall()
        c = baglanti.execute("Select hafiza from cfirmasi  ").fetchall()
        plt.plot(a, color = "blue", label = "A firmasının telefonların Hafızası")
        plt.plot(b, color = "red", label = "B firmasının telefonların Hafızası")
        plt.plot(c, color = "pink", label = "c firmasının telefonların Hafızası")
        plt.title("Firmaların telefonların Hafıza karşılaştırmaları ")
        plt.xlabel("Firmalar")
        plt.ylabel("Oranlar")
        plt.legend()
        plt.show()
    def toplu():
        a = baglanti.execute("Select ram from afirmasi  ").fetchall()
        b = baglanti.execute("Select ram from bfirmasi  ").fetchall()
        c = baglanti.execute("Select ram from cfirmasi  ").fetchall()
        plt.plot(a, color = "blue", label = "A firmasının telefonların Ramı")
        plt.plot(b, color = "red", label = "B firmasının telefonların Ramı")
        plt.plot(c, color = "pink", label = "c firmasının telefonların Ramı")
        d = baglanti.execute("Select battery from afirmasi  ").fetchall()
        e = baglanti.execute("Select battery from bfirmasi  ").fetchall()
        f = baglanti.execute("Select battery from cfirmasi  ").fetchall()
        plt.plot(d, color = "white", label = "A firmasının telefonların bataryası")
        plt.plot(e, color = "purple", label = "B firmasının telefonların bataryası")
        plt.plot(f, color = "orange", label = "c firmasının telefonların bataryası")
        g = baglanti.execute("Select kamera from afirmasi  ").fetchall()
        h = baglanti.execute("Select kamera from bfirmasi  ").fetchall()
        l = baglanti.execute("Select kamera from cfirmasi  ").fetchall()
        plt.plot(g, color = "green", label = "A firmasının telefonların kamera pikseli")
        plt.plot(h, color = "gray", label = "B firmasının telefonların kamera pikseli")
        plt.plot(l, color = "pink", label = "c firmasının telefonların kamera pikseli")
        z = baglanti.execute("Select hafiza from afirmasi  ").fetchall()
        x = baglanti.execute("Select hafiza from bfirmasi  ").fetchall()
        y = baglanti.execute("Select hafiza from cfirmasi  ").fetchall()
        plt.plot(z, color = "gray", label = "A firmasının telefonların Hafızası")
        plt.plot(x, color = "orange", label = "B firmasının telefonların Hafızası")
        plt.plot(y, color = "pink", label = "c firmasının telefonların Hafızası")
        plt.title("Firmalar Cep Telefonları Tüm Karşılaştırmaları ")
        plt.xlabel("Firmalar")
        plt.ylabel("Oranlar")
        plt.legend()
        plt.show()
    
    def anamenu():
        
        secim = input("Hangi özelliklerini karşılaştırmak istersiniz: \n (ram/batarya/kamera/hafıza/toplu) \n")
        if secim == "ram":
            karsilastirma.ram()
        elif secim == "batarya":
            karsilastirma.battery()
        elif secim == "kamera":
            karsilastirma.camera()
        elif secim == "hafıza":
            karsilastirma.hafiza()
        elif secim == "toplu":
            karsilastirma.toplu()
        else:
            print("Yanlış bir tuşlama yaptınız.")
def kaydet():
    analiz = input("Firmalar hangindeki gözlemlerinizi yazın:")
    dosya = open("rapor.txt", "r")
        if os.path.getsize('rapor.txt') == 0:
            with open('rapor.txt', 'w', encoding='utf-8') as dosyam:
                dosyam.write(','.join(analiz)) 
        else:
            with open('rapor.txt', 'a', encoding='utf-8') as dosyam:
                dosyam.write(','.join(analiz)) 
    
def arama():
    secim = input("Hangi firmanın ürünlerini arama yapmak istiyorsunuz: (A/B/C) \n")
    if secim == "a" or secim == "A":
        try:
            a = baglanti.execute("SELECT * FROM afirmasi").fetchall()
        except:
            print("Arama yapılamadı.")
        finally:
            print(a)
    elif secim == "b" or secim == "B":
        try:
            b = baglanti.execute("SELECT * FROM bfirmasi").fetchall()
        except:
            print("Arama yapılamadı.")
        finally:
            print(b)
    elif secim == "C" or secim == "c":
        try:
            c = baglanti.execute("SELECT * FROM cfirmasi").fetchall()
        except:
            print("Arama yapılamadı.")
        finally:
            print(c)
    else:
        print("Yanlış bir tuşlama yaptınız.")
                                 
def ekle():
    telefonadi = input("Telefon adını giriniz: \n")
    kamera = int(input("Kamera kaç piksel giriniz: \n "))
    telefon = int(input("İos//Android mi? (0/1): \n "))
    hafiza = int(input("Hafıza ne kadar giriniz: \n "))
    ram = int(input("Kaç RAM ı var giriniz: \n "))
    battery = int(input("Bateri kaç miniamper giriniz: \n "))

    secim = input("Hangi firmaya ekleme yapmak istiyorsunuz: (A/B/C) \n")
    if secim == "a" or secim == "A":
        try:
            baglanti.execute("INSERT INTO afirmasi(telefonadi,kamera,telefon,hafiza,ram,battery) VALUES ('{}','{}','{}','{}','{}','{}')".format(telefonadi,kamera,telefon,hafiza,ram,battery))
            baglanti.commit()
        except:
            print("Ekleme yapılamadı.")
        finally:
            print("Ekleme başarıyla yapıldı.")
    elif secim == "b" or secim == "B":
        try:
            baglanti.execute("INSERT INTO bfirmasi(telefonadi,kamera,telefon,hafiza,ram,battery) VALUES ('{}','{}','{}','{}','{}','{}')".format(telefonadi,kamera,telefon,hafiza,ram,battery))
            baglanti.commit()
        except:
            print("Ekleme yapılamadı.")
        finally:
            print("Ekleme başarıyla yapıldı.")
    elif secim == "C" or secim == "c":
        try:
            baglanti.execute("INSERT INTO cfirmasi(telefonadi,kamera,telefon,hafiza,ram,battery) VALUES ('{}','{}','{}','{}','{}','{}')".format(telefonadi,kamera,telefon,hafiza,ram,battery))
            baglanti.commit()
        except:
            print("Ekleme yapılamadı.")
        finally:
            print("Ekleme başarıyla yapıldı.")
    else:
        print("Yanlış bir tuşlama yaptınız.")
def anamenu():
    print("-" * 50, "Marka analizi programımıza hoşgeldiniz", "-" * 50)
    secim = input("Ne yapmak istiyorsunuz: \n 1-) Cep telefonu ekle \n 2-) Arama yap \n 3-) Karşılaştırma yap \n 4-) Gözlemleri kaydet. \n " )
    if secim == "1":
        ekle()
    elif secim == "2":
        arama()
    elif secim == "3":
        karsilastirma.anamenu()
    elif secim == "4":
        kaydet()
    else:
        print("Hatalı bir tuşlama yaptınız.")
        
anamenu()
# Out:
# -------------------------------------------------- Marka analizi programımıza hoşgeldiniz --------------------------------------------------
# Ne yapmak istiyorsunuz:
#  1-) Cep telefonu ekle
#  2-) Arama yap
#  3-) Karşılaştırma yap
# 3
# Hangi özelliklerini karşılaştırmak istersiniz:
#  (ram/batarya/kamera/hafıza/toplu)
# toplu

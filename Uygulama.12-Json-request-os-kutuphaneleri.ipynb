# %%
import json
import requests
import os

def doviz():
    request = requests.post('https://api.genelpara.com/embed/doviz.json')
    veri = request.json()
    for i in veri:
        print("1 Türk lirası Satış/Alış ", i, "=", veri[i]["satis"], veri[i]["alis"], veri[i]["degisim"])
        print("-" * 100)
class news:
    def yazdir(a):
        dosya = open("haber.txt", "r")
        if os.path.getsize('haber.txt') == 0:
            with open('haber.txt', 'w', encoding='utf-8') as dosyam:
                dosyam.write(','.join(a)) 
        else:
            with open('haber.txt', 'a', encoding='utf-8') as dosyam:
                dosyam.write(','.join(a)) 
    def health():
        url = ('https://newsdata.io/api/1/news?apikey=pub_1603719e62489b790d8cf1d4f6a6f6ada2ee5&q=health')
        veri = requests.get(url)
        veritu = veri.json()
        for i in veritu:
            result = veritu['results']
            for a in result:
                b = ("Başlık:", a['title'], "\n" , "Metin" , "\n", a['description'], "\n")
                secim = input("Dosyaya kaydetmek istiyor musunuz?(E/H) \n")
                if secim == "E" or secim == "e":
                    news.yazdir(b)
                elif secim == "H" or secim == "h":
                    print("Program sona erdi.")
                else:
                    print("Hatalı bir tuşlama yaptınız.")
    def teknoloji():
        url = ('https://newsdata.io/api/1/news?apikey=pub_1603719e62489b790d8cf1d4f6a6f6ada2ee5&q=technology')
        veri = requests.get(url)
        veritu = veri.json()
        for i in veritu:
            result = veritu['results']
            for a in result:
                b = ("Başlık:", a['title'], "\n" , "Metin" , "\n", a['description'], "\n")
                secim = input("Dosyaya kaydetmek istiyor musunuz?(E/H) \n")
                if secim == "E" or secim == "e":
                    news.yazdir(b)
                elif secim == "H" or secim == "h":
                    print("Program sona erdi.")
                else:
                    print("Hatalı bir tuşlama yaptınız.")
    def siyaset():
        url = ('https://newsdata.io/api/1/news?apikey=pub_1603719e62489b790d8cf1d4f6a6f6ada2ee5&q=politics')
        veri = requests.get(url)
        veritu = veri.json()
        for i in veritu:
            result = veritu['results']
            for a in result:
                b = ("Başlık:", a['title'], "\n" , "Metin" , "\n", a['description'], "\n")
                secim = input("Dosyaya kaydetmek istiyor musunuz?(E/H) \n")
                if secim == "E" or secim == "e":
                    news.yazdir(b)
                elif secim == "H" or secim == "h":
                    print("Program sona erdi.")
                else:
                    print("Hatalı bir tuşlama yaptınız.")
    def economy():
        url = ('https://newsdata.io/api/1/news?apikey=pub_1603719e62489b790d8cf1d4f6a6f6ada2ee5&q=economy')
        veri = requests.get(url)
        veritu = veri.json()
        for i in veritu:
            result = veritu['results']
            for a in result:
                b = ("Başlık:", a['title'], "\n" , "Metin" , "\n", a['description'], "\n")
                secim = input("Dosyaya kaydetmek istiyor musunuz?(E/H) \n")
                if secim == "E" or secim == "e":
                    news.yazdir(b)
                elif secim == "H" or secim == "h":
                    print("Program sona erdi.")
                else:
                    print("Hatalı bir tuşlama yaptınız.")
    def sports():
        url = ('https://newsdata.io/api/1/news?apikey=pub_1603719e62489b790d8cf1d4f6a6f6ada2ee5&q=sport')
        veri = requests.get(url)
        veritu = veri.json()
        for i in veritu:
            result = veritu['results']
            for a in result:
                b = ("Başlık:", a['title'], "\n" , "Metin" , "\n", a['description'], "\n")
                secim = input("Dosyaya kaydetmek istiyor musunuz?(E/H) \n")
                if secim == "E" or secim == "e":
                    news.yazdir(b)
                elif secim == "H" or secim == "h":
                    print("Program sona erdi.")
                else:
                    print("Hatalı bir tuşlama yaptınız.")
   

    def secim():
        secim = input("Hangi kategori haberlerine bakmak istiyorsunuz: \n 1-) Sağlık \n 2-) Teknoloji \n 3-) Siyaset \n 4-) Ekonomi \n 5-) Spor \n")
        if secim == "1":
            news.health()
        elif secim == "2":
            new.teknoloji()
        elif secim == "3":
            new.siyaset()
        elif secim == "4":
            new.economy()
        elif secim == "5":
            new.sports()
        else:
            print("Hatalı bir tuşlama yaptınız.")
            
def anamenu():
    print("-" * 50,"Request ve Json Öğrenme Programımıza Hoşgeldiniz", "*" * 50)
    secim = input("Ne yapmak istersiniz: \n 1-) Türk Lirasının Diğer Para Birimlerine olan karşılığı görmek \n 2-) Haberlere bak: \n ")
    if secim == "1":
        doviz()
    elif secim == "2":
        news.secim()
    else:
        print("Hatalı bir tuşlama yaptınız.")

anamenu()
# Out:
# -------------------------------------------------- Request ve Json Öğrenme Programımıza Hoşgeldiniz **************************************************
# Ne yapmak istersiniz:
#  1-) Türk Lirasının Diğer Para Birimlerine olan karşılığı görmek
#  2-) Haberlere bak:
#  2
# Hangi kategori haberlerine bakmak istiyorsunuz:
#  1-) Sağlık
#  2-) Teknoloji
#  3-) Siyaset
#  4-) Ekonomi
#  5-) Spor
# 1
# Dosyaya kaydetmek istiyor musunuz?(E/H)
# e
# Dosyaya kaydetmek istiyor musunuz?(E/H)
# e
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-186e1342daae> in <module>
#      94         print("Hatalı bir tuşlama yaptınız.")
#      95
# ---> 96 anamenu()
#      97
#
# <ipython-input-55-186e1342daae> in anamenu()
#      90         doviz()
#      91     elif secim == "2":
# ---> 92         news.secim()
#      93     else:
# ...
